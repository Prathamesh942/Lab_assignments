# %%
import pandas as pd

# %%
df = pd.read_csv('car.csv')

# %%
ndf = df

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1553 non-null   int64
#  1   car_name            1553 non-null   object
#  2   registration_year   1553 non-null   object
#  3   insurance_validity  1553 non-null   object
#  4   fuel_type           1553 non-null   object
#  5   seats               1553 non-null   int64
#  6   kms_driven          1553 non-null   int64
#  7   ownsership          1553 non-null   object
#  8   transmission        1553 non-null   object
#  9   manufacturing_year  1553 non-null   object
#  10  mileage(kmpl)       1550 non-null   float64
#  11  engine(cc)          1550 non-null   float64
#  12  max_power(bhp)      1550 non-null   float64
#  13  torque(Nm)          1549 non-null   float64
#  14  price(in lakhs)     1553 non-null   float64
# ...

# %%
ndf.describe()
# Out:
#         Unnamed: 0         seats     kms_driven  mileage(kmpl)    engine(cc)  \
# count  1553.000000   1553.000000    1553.000000    1550.000000  1.550000e+03
# mean    776.000000     91.480361   52841.931101     236.927277  1.471857e+10
# std     448.456798   2403.424060   40067.800347     585.964295  2.185629e+11
# min       0.000000      4.000000     620.000000       7.810000  5.000000e+00
# 25%     388.000000      5.000000   30000.000000      16.342500  1.197000e+03
# 50%     776.000000      5.000000   49134.000000      18.900000  1.462000e+03
# 75%    1164.000000      5.000000   70000.000000      22.000000  1.995000e+03
# max    1552.000000  67000.000000  810000.000000    3996.000000  3.258640e+12
#
#        max_power(bhp)    torque(Nm)  price(in lakhs)
# count    1.550000e+03  1.549000e+03      1553.000000
# mean     1.471857e+10  1.423989e+04       166.141494
# std      2.185629e+11  9.666241e+04      3478.855090
# min      5.000000e+00  5.000000e+00         1.000000
# ...

# %%
ndf.head()
# Out:
#    Unnamed: 0                                           car_name  \
# 0           0                    2017 Mercedes-Benz S-Class S400
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
# 3           3                           2019 Kia Seltos GTX Plus
# 4           4                    2019 Skoda Superb LK 1.8 TSI AT
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 0            Jul-17      Comprehensive    Petrol      5       56000
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
# 3            Dec-19      Comprehensive    Petrol      5       18378
# 4            Aug-19      Comprehensive    Petrol      5       44900
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 0  First Owner    Automatic               2017           7.81      2996.0
# ...

# %%
ndf.sample()
# Out:
#       Unnamed: 0              car_name registration_year insurance_validity  \
# 1327        1327  2013 Maruti Ritz LDi            Oct-13      Comprehensive
#
#      fuel_type  seats  kms_driven   ownsership transmission  \
# 1327    Diesel      5      100500  Third Owner       Manual
#
#      manufacturing_year  mileage(kmpl)  engine(cc)  max_power(bhp)  \
# 1327               2013         1248.0      7394.0          7394.0
#
#       torque(Nm)  price(in lakhs)
# 1327       190.0             2.45

# %%
ndf.sample(10)
# Out:
#       Unnamed: 0                                  car_name registration_year  \
# 869          869            2018 Hyundai Verna VTVT 1.6 SX            Apr-18
# 1289        1289             2020 Maruti Alto 800 VXI BSVI            Dec-20
# 373          373        2018 Toyota Innova Crysta 2.4 G MT            Jul-18
# 737          737        2015 Hyundai Grand i10 Asta Option            May-15
# 1347        1347                2011 Hyundai i10 Sportz AT            Aug-11
# 1016        1016                      2013 Hyundai i10 Era            Mar-13
# 1109        1109                 2014 Hyundai i20 Asta 1.2            May-14
# 901          901            2020 Volvo XC60 D5 Inscription            Aug-20
# 493          493             2015 Honda City i VTEC CVT VX            Nov-15
# 1439        1439  2021 Hyundai i20 Asta Opt Turbo DCT BSVI            Mar-21
#
#      insurance_validity fuel_type  seats  kms_driven    ownsership  \
# ...

# %%
ndf.tail()
# Out:
#       Unnamed: 0                                  car_name registration_year  \
# 1548        1548  2020 Hyundai Creta SX Opt Diesel AT BSVI            Aug-20
# 1549        1549        2022 Renault KWID 1.0 RXL Opt BSVI              2022
# 1550        1550                  2017 Honda WR-V i-VTEC S            Jun-17
# 1551        1551  2018 Volkswagen Polo 1.0 MPI Comfortline            May-18
# 1552        1552               2018 Maruti Swift Dzire VXI            May-18
#
#          insurance_validity fuel_type  seats  kms_driven    ownsership  \
# 1548          Comprehensive    Diesel      5       35000   First Owner
# 1549  Third Party insurance    Petrol      5       10000        999 cc
# 1550          Comprehensive    Petrol      5       49000   First Owner
# 1551          Comprehensive    Petrol      5       40000  Second Owner
# 1552          Comprehensive    Petrol      5       34756   First Owner
#
#      transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# ...

# %%
ndf.shape
# Out:
# (1553, 15)

# %%
ndf.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
ndf['fuel_type'] = ndf['fuel_type'].replace({'Petrol':1,'Diesel':2})

# %%
ndf.sample()
# Out:
#       Unnamed: 0                        car_name registration_year  \
# 1266        1266  2015 Hyundai Grand i10 AT Asta            Nov-15
#
#      insurance_validity fuel_type  seats  kms_driven    ownsership  \
# 1266        Third Party         1      5       77299  Second Owner
#
#      transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1266    Automatic               2015           18.9      1197.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)
# 1266          1197.0        82.0             4.79

# %%
ndf.dtypes
# Out:
# Unnamed: 0              int64
# car_name               object
# registration_year      object
# insurance_validity     object
# fuel_type              object
# seats                   int64
# kms_driven              int64
# ownsership             object
# transmission           object
# manufacturing_year     object
# mileage(kmpl)         float64
# engine(cc)            float64
# max_power(bhp)        float64
# torque(Nm)            float64
# price(in lakhs)       float64
# dtype: object

# %%
meanmil = ndf['mileage(kmpl)'].mean()

# %%
meanmil
# Out:
# 236.92727741935482

# %%
ndf['mileage(kmpl)'].fillna(meanmil, inplace=True)
# Out:
# C:\Users\91766\AppData\Local\Temp\ipykernel_2444\3208096060.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ndf['mileage(kmpl)'].fillna(meanmil, inplace=True)

# %%
ndf.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
ndf['torque(Nm)'].fillna(ndf['torque(Nm)'].mean(), inplace=True)
# Out:
# C:\Users\91766\AppData\Local\Temp\ipykernel_2444\2106386296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ndf['torque(Nm)'].fillna(ndf['torque(Nm)'].mean(), inplace=True)

# %%
ndf.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64
